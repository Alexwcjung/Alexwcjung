# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexwcjung/Alexwcjung/blob/main/pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/HFwords.csv")

# %%
print(df)
# Out:
#     Word  Frequency
# 0    the       1951
# 1     be       3455
# 2     to       4798
# 3     of       3822
# 4    and       3969
# 5      a       3129
# 6     in       3312
# 7   that       1794
# 8   have       2103
# 9      I       2117
# 10    it       3484
# 11   for       3906
# 12   not       4751
# 13    on       2548
# 14  with       1868
# 15    he       1384
# 16    as       3638
# 17   you       3929
# 18    do       2726
# 19    at       4619
# 20  this       2598
# 21   but       4337
# 22   his       2118
# 23    by       2621
# 24  from       1871
# 25  they       4787
# 26    we       1032
# 27   say       3828
# 28   her       3543
# 29   she       3707

# %%
df.head(5)
# Out:
#   Word  Frequency
# 0  the       1951
# 1   be       3455
# 2   to       4798
# 3   of       3822
# 4  and       3969

# %%
url = "https://raw.githubusercontent.com/Alexwcjung/Corpus2024/main/HFwords.csv"
